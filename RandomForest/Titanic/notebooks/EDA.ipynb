# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "../data/raw/train.csv"
train = pd.read_csv(path)

# %%
df = train.copy()

df["Age_mean_by_Pclass"] = df.groupby("Pclass")["Age"].transform("mean")
display
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 df = train.copy()
# ----> 3 df["Age_mean_by_Pclass"] = df.groupby("Pclass")["Age"]
#       4 display(df)
#
# File ~/Projects/assignment_practice/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~/Projects/assignment_practice/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
# ...

# %%
grouped = train.groupby("Pclass")
print(grouped)
for group_name, group_df in grouped:
    display(f"Group: {group_name}")
    display(group_df.head())
# Out:
# ...
# 'Group: 1'
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S
# 'Group: 2'
# ...

# %%
# 1. Quick peek
display(train.head(10))


# 2. Data info (types, missing)
print(train.info())

# 3. Summary statistics for numeric features
print(train.describe())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
for col in train.columns:
    print(f"\nColumn: {col}")
    print(train[col].map(type).value_counts())
# Out:
# Column: PassengerId
# PassengerId
# <class 'int'>    891
# Name: count, dtype: int64
#
# Column: Survived
# Survived
# <class 'int'>    891
# Name: count, dtype: int64
#
# Column: Pclass
# Pclass
# <class 'int'>    891
# Name: count, dtype: int64
#
# Column: Name
# Name
# <class 'str'>    891
# Name: count, dtype: int64
#
# Column: Sex
# Sex
# <class 'str'>    891
# Name: count, dtype: int64
#
# Column: Age
# Age
# <class 'float'>    891
# Name: count, dtype: int64
#
# Column: SibSp
# SibSp
# <class 'int'>    891
# Name: count, dtype: int64
#
# Column: Parch
# Parch
# <class 'int'>    891
# Name: count, dtype: int64
#
# Column: Ticket
# Ticket
# <class 'str'>    891
# Name: count, dtype: int64
#
# Column: Fare
# Fare
# <class 'float'>    891
# Name: count, dtype: int64
#
# Column: Cabin
# Cabin
# <class 'float'>    687
# <class 'str'>      204
# Name: count, dtype: int64
#
# Column: Embarked
# Embarked
# <class 'str'>      889
# <class 'float'>      2
# Name: count, dtype: int64

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
